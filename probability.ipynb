# %%
# probability 


# 1. event 
# 2. probability of an event
# 3. sample space
# 4. dependent and independent events
# 5. mutually exclusive events
# 6. completely exhaustive events
# 7. union and intersection of events 
# 8. conditonal probability                                         What is the probability that a card is a heart (H) given that it is red (R)?
# 9. Bays therom
# 10. random variables
# 11. probability distribution
