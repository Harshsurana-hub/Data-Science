# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh-9389/DA/blob/master/num_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Array Creation

# array()
# zeros()
# ones()
# empty()
# full()
# arange()
# linspace()


# Array Inspection

# shape
# size  // total number of elements
# dtype

# broadcasting
# vector and matrices operations and comparision with list operations

# Important

# reshape()
# transpose()
# concatenate()
# where()
# sort()
# sum()
# mean()
# std()
# min()
# max()
# unique()
# matmul()
# random.randint()
# random.choice()  // choice from a perticular given array

# %%
import numpy as np

# %%
scores = input().split()
print(scores)

scores = [int(x) for x in scores]
print(scores)
# Out:
# 3 4 5 6
# ['3', '4', '5', '6']
# [3, 4, 5, 6]

# %%
# Question 1
a = np.array([3, 3,3 ,3])

b = a
b[0] = 1

print(a, b)
# Out:
# [3 3 3 3] [1 3 3 3]

# %%
# Question 2

np_arr = np.array([3,3,3,3, 3.3, 'hello', False])
print(np_arr)
# print(bool(np_arr[-1]))

# a = False
# print(bool(a))
# Out:
# ['3' '3' '3' '3' '3.3' 'hello' 'False']

# %%
a = '0'
print(bool(a))
# Out:
# True

# %%
import numpy as np

# %%
a = np.array([1, 3, 9, 0, 'hello'])
print(a)
# Out:
# ['1' '3' '9' '0' 'hello']

# %%
a = np.full(4, 5, dtype=int)
print(a)
# Out:
# [5 5 5 5]
